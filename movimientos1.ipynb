# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/etl-data-pipeline-1704712021-/blob/main/movimientos1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline-1704712021-/refs/heads/main/Data/E_movimientos.csv"

# %%
df = pd. read_csv(url)

# %%
display(df.head())
# Out:
#   id_movimiento id_inventario tipo_movimiento       fecha cantidad_movimiento
# 0       MOV9000       INV5000          ajuste  2025-03-05                  15
# 1       MOV9001       INV5122          ajuste  2024-03-06              73 uds
# 2       MOV9002       INV5019          salida  2024-05-27                  30
# 3       MOV9003       INV5110         entrada  2025-01-16                  44
# 4       MOV9004       INV5152         entrada  2024-08-28                  55

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
for col in df.select_dtypes(include="object").columns:df[col] = df[col].str.strip()

# %%
df["motivo_rechazo"]=""
