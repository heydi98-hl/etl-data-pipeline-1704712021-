# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/etl-data-pipeline-1704712021-/blob/main/inventario1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline-1704712021-/refs/heads/main/Data/E_inventario.csv"

# %%
df = pd. read_csv(url)

# %%
display(df.head())
# Out:
#   id_inventario id_bodega            item cantidad costo_unitario
# 0       INV5000    BOD103     Producto 45      359         192.81
# 1       INV5001    BOD111      Producto 2      419         153.48
# 2       INV5002    BOD999   Producto 120        58         104.91
# 3       INV5003    BOD100     Producto 42      422       $ 138.66
# 4       INV5004    BOD112     Producto 79      257            NaN

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
for col in df.select_dtypes(include="object").columns:df[col] = df[col].str.strip()

# %%
df["motivo_rechazo"]=""
