# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/etl-data-pipeline-1704712021-/blob/main/bodegas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline-1704712021-/refs/heads/main/Data/E_bodegas.csv"

# %%
df = pd. read_csv(url)

# %%
display(df.head())
# Out:
#   id_bodega       bodega   ubicacion capacidad_m2
# 0    BOD100   Central 0     Usulután      1292 m2
# 1    BOD101        Sur 1  San Miguel         2047
# 2    BOD102    Central 2   Sonsonate       651 m2
# 3    BOD103  Occidente 3  San Miguel         2250
# 4    BOD104        Sur 4   Santa Ana          239

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
for col in df.select_dtypes(include="object").columns:df[col] = df[col].str.strip()

# %%
df["motivo_rechazo"]=""

# %%
# !pip install sqlalchemy psycopg2-binary

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
database_url = "postgresql://bodegas_9uuy_user:HuICklFaNVCMo69Qx7aReXuPaqB1FLk7@dpg-d6vib4fdiees73d3o0kg-a.oregon-postgres.render.com/bodegas_9uuy"

# %%
engine = create_engine("postgresql://bodegas_9uuy_user:HuICklFaNVCMo69Qx7aReXuPaqB1FLk7@dpg-d6vib4fdiees73d3o0kg-a.oregon-postgres.render.com/bodegas_9uuy")

# %%
test = pd.read_sql("SELECT 1", engine)

# %%
print(test)
# Out:
#    ?column?
# 0         1

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline-1704712021-/refs/heads/main/Data/E_bodegas.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   id_bodega       bodega   ubicacion capacidad_m2
# 0    BOD100   Central 0     Usulután      1292 m2
# 1    BOD101        Sur 1  San Miguel         2047
# 2    BOD102    Central 2   Sonsonate       651 m2
# 3    BOD103  Occidente 3  San Miguel         2250
# 4    BOD104        Sur 4   Santa Ana          239

# %%
df.shape
# Out:
# (20, 4)

# %%
df.columns
# Out:
# Index(['id_bodega', 'bodega', 'ubicacion', 'capacidad_m2'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_bodega     18 non-null     object
#  1   bodega        20 non-null     object
#  2   ubicacion     20 non-null     object
#  3   capacidad_m2  20 non-null     object
# dtypes: object(4)
# memory usage: 772.0+ bytes

# %%
df.isnull().sum()
# Out:
# id_bodega       2
# bodega          0
# ubicacion       0
# capacidad_m2    0
# dtype: int64

# %%
clientes = df.copy()

# %%
clientes.columns = clientes.columns.str.strip().str.lower()

# %%
for col in clientes.select_dtypes(include='object').columns:

    clientes[col] = clientes[col].astype(str).str.strip()

# %%
clientes = clientes.replace(r'^\s*$', pd.NA, regex=True)

# %%
clientes = clientes.drop_duplicates()

# %%
def motivo(row):



    motivos = []

# %%
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
import pandas as pd

database_url = "postgresql://etl_user:H1p5ZGWEjVtVLYwGVZgLHieAbGWE48cy@dpg-d6qt0ecr85hc73f3paqg-a.oregon-postgres.render.com/etl_seguros"

engine = create_engine(database_url)

test = pd.read_sql("SELECT 1", engine)

print(test)
# Out:
# ...
#    ?column?
# 0         1

# %%
pd.read_sql(

"SELECT * FROM clientes_curated LIMIT 10",

engine

)
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
# 5           6  Ricardo López Vásquez  ricardo.lopez.vasquez6@seguro.sv
# 6           7     Diego Flores Rojas   diego.flores.rojas0@example.com
# 7           8      Karla Ortiz López       karla.ortiz.lopez1@mail.com
# 8           9    Juan Flores Morales  juan.flores.morales2@example.com
# 9          10    María Aguilar López  maria.aguilar.lopez3@example.com
#
#       genero fecha_nacimiento        ciudad segmento
# 0     Hombre       2011-11-24     SanMiguel      nan
# 1        nan              NaT      Sta. Ana      nan
# ...
