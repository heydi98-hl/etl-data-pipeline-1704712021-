# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/etl-data-pipeline-1704712021-/blob/main/inventario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sqlalchemy psycopg2-binary

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
database_url = "postgresql://inventario_ckin_user:mNIfbaImssru3pIrY3Q0P01sxw9YQaWM@dpg-d6viv51r0fns73cakigg-a.oregon-postgres.render.com/inventario_ckin"

# %%
engine = create_engine("postgresql://inventario_ckin_user:mNIfbaImssru3pIrY3Q0P01sxw9YQaWM@dpg-d6viv51r0fns73cakigg-a.oregon-postgres.render.com/inventario_ckin")

# %%
test = pd.read_sql("SELECT 1", engine)

# %%
print(test)
# Out:
#    ?column?
# 0         1

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline-1704712021-/refs/heads/main/Data/E_inventario.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   id_inventario id_bodega            item cantidad costo_unitario
# 0       INV5000    BOD103     Producto 45      359         192.81
# 1       INV5001    BOD111      Producto 2      419         153.48
# 2       INV5002    BOD999   Producto 120        58         104.91
# 3       INV5003    BOD100     Producto 42      422       $ 138.66
# 4       INV5004    BOD112     Producto 79      257            NaN

# %%
df.shape
# Out:
# (166, 5)

# %%
df.columns
# Out:
# Index(['id_inventario', 'id_bodega', 'item', 'cantidad', 'costo_unitario'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_inventario   166 non-null    object
#  1   id_bodega       161 non-null    object
#  2   item            166 non-null    object
#  3   cantidad        161 non-null    object
#  4   costo_unitario  161 non-null    object
# dtypes: object(5)
# memory usage: 6.6+ KB

# %%
df.isnull().sum()
# Out:
# id_inventario     0
# id_bodega         5
# item              0
# cantidad          5
# costo_unitario    5
# dtype: int64

# %%
clientes = df.copy()

# %%
clientes.columns = clientes.columns.str.strip().str.lower()

# %%
for col in clientes.select_dtypes(include='object').columns:

    clientes[col] = clientes[col].astype(str).str.strip()

# %%
clientes = clientes.replace(r'^\s*$', pd.NA, regex=True)

# %%
clientes = clientes.drop_duplicates()

# %%
def motivo(row):



    motivos = []

# %%
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
import pandas as pd

database_url = "postgresql://etl_user:H1p5ZGWEjVtVLYwGVZgLHieAbGWE48cy@dpg-d6qt0ecr85hc73f3paqg-a.oregon-postgres.render.com/etl_seguros"

engine = create_engine(database_url)

test = pd.read_sql("SELECT 1", engine)

print(test)
# Out:
# ...
#    ?column?
# 0         1

# %%
pd.read_sql(

"SELECT * FROM clientes_curated LIMIT 10",

engine

)
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
# 5           6  Ricardo López Vásquez  ricardo.lopez.vasquez6@seguro.sv
# 6           7     Diego Flores Rojas   diego.flores.rojas0@example.com
# 7           8      Karla Ortiz López       karla.ortiz.lopez1@mail.com
# 8           9    Juan Flores Morales  juan.flores.morales2@example.com
# 9          10    María Aguilar López  maria.aguilar.lopez3@example.com
#
#       genero fecha_nacimiento        ciudad segmento
# 0     Hombre       2011-11-24     SanMiguel      nan
# 1        nan              NaT      Sta. Ana      nan
# ...
